# %%
                                                 NUMPY
definition:
        NumPy (Numerical Python) is a Python library used for creating arrays and performing fast mathematical and numerical operations


No.   Function                            Uses                                            Example                     
  
  1      np.array()                 Creates an array                                     np.array([1,2,3])
  2      np.zeros()                 Creates an array filled with zeros                   np.zeros((2,3))
  3      np.ones()                  Creates an array filled with ones                    np.ones((2,2))
  4      np.arange()                Creates a sequence of numbers                        np.arange(1,11)
  5      np.linspace()              Creates evenly spaced values                         np.linspace(0,10,5)
  6      np.random.randint()        Generates random integers                            np.random.randint(1,10,5)
  7      reshape()                  Changes the shape of an array                        arr.reshape(2,3)
  8      flatten()                  Converts a multi-dimensional array into a 1D array   arr.flatten()
  9      np.sum()                   Calculates the sum of array elements                 np.sum(arr)
  10     np.mean()                  Calculates the average of array elements             np.mean(arr)
  11     np.max()                   Finds the maximum value                              np.max(arr)
  12     np.min()                   Finds the minimum value                              np.min(arr)
  13     np.sort()                  Sorts the array elements                             np.sort(arr)
  14     np.unique()                Returns unique elements by removing duplicates       np.unique(arr)
  15     np.transpose()             Transposes the array (swaps rows and columns)        arr.T

# %%
                                       PANDAS
definition:
        Pandas is a Python library used for data manipulation, analysis, and working with tabular data using DataFrames and Series


 No.       Function                 Uses                                   Example
    
 1     pd.DataFrame()   Creates a DataFrame                      pd.DataFrame(data)                    
 2     pd.Series()      Creates a Series                         pd.Series([10,20,30])                 
 3     pd.read_csv()    Reads a CSV file                         pd.read_csv("data.csv")               
 4     head()           Displays the first 5 rows                df.head()                             
 5     tail()           Displays the last 5 rows                 df.tail()                             
 6     info()           Displays DataFrame information           df.info()                             
 7     describe()       Displays statistical summary             df.describe()                         
 8     shape            Returns the number of rows and columns   df.shape                              
 9     columns          Returns column names                     df.columns                            
 10    drop()           Removes rows or columns                  df.drop("Age", axis=1)                
 11    rename()         Renames columns                          df.rename(columns={"Name":"Student"}) 
 12    sort_values()    Sorts data by a column                   df.sort_values("Marks")              
 13    isnull()         Checks for missing values                df.isnull()                           
 14    fillna()         Fills missing values                     df.fillna(0)                          
 15    groupby()        Groups data by a column                  df.groupby("Department")

# %%
                                   MATHPLOTLIB
definition:
        Matplotlib is a Python library used for creating graphs, charts, and data visualizations


 No.     Function                  Uses                    Example                     
 
 1     plt.plot()       Creates a line plot          plt.plot(x, y)           
 2     plt.scatter()    Creates a scatter plot       plt.scatter(x, y)         
 3     plt.bar()        Creates a bar chart          plt.bar(x, y)          
 4     plt.hist()       Creates a histogram          plt.hist(data)            
 5     plt.pie()        Creates a pie chart          plt.pie(values)           
 6     plt.title()      Adds a title to the plot     plt.title("Sales")        
 7     plt.xlabel()     Sets the x-axis label        plt.xlabel("Month")       
 8     plt.ylabel()     Sets the y-axis label        plt.ylabel("Sales")       
 9     plt.legend()     Displays the legend          plt.legend()        
 10    plt.grid()       Displays grid lines          plt.grid(True)            
 11    plt.xlim()       Sets x-axis limits           plt.xlim(0, 10)           
 12    plt.ylim()       Sets y-axis limits           plt.ylim(0, 100)          
 13    plt.figure()     Creates a new figure         plt.figure(figsize=(6,4)) 
 14    plt.savefig()    Saves the plot as an image   plt.savefig("chart.png")  
 15    plt.show()       Displays the plot            plt.show()

# %%
                                           SEABORN
definition:
        Seaborn is a Python data visualization library built on Matplotlib, used for creating attractive and informative statistical graphs


 No.      Function                      Uses                                          Example 

 1     sns.lineplot()         Creates a line plot                             sns.lineplot(x="Month", y="Sales", data=df)           
 2     sns.scatterplot()      Creates a scatter plot                          sns.scatterplot(x="Age", y="Salary", data=df)         
 3     sns.barplot()          Creates a bar chart                             sns.barplot(x="Dept", y="Marks", data=df)             
 4     sns.histplot()         Creates a histogram                             sns.histplot(data=df, x="Age")                        
 5     sns.boxplot()          Creates a box plot                              sns.boxplot(x="Gender", y="Salary", data=df)       
 6     sns.violinplot()       Creates a violin plot                           sns.violinplot(x="Gender", y="Marks", data=df)        
 7     sns.countplot()        Counts and displays category frequencies        sns.countplot(x="Department", data=df)         
 8     sns.heatmap()          Creates a heatmap                               sns.heatmap(df.corr())                 
 9     sns.pairplot()         Shows pairwise relationships                    sns.pairplot(df)                                
 10    sns.jointplot()        Shows the relationship between two variables    sns.jointplot(x="Age", y="Salary", data=df)           
 11    sns.kdeplot()          Plots data distribution                         sns.kdeplot(data=df, x="Marks")             
 12    sns.regplot()          Creates a regression plot                       sns.regplot(x="Age", y="Salary", data=df)             
 13    sns.catplot()          Creates categorical plots                       sns.catplot(x="Dept", y="Marks", kind="bar", data=df)
 14    sns.set_style()        Sets the plot style                             sns.set_style("darkgrid")              
 15    sns.color_palette()    Sets or returns color palettes                  sns.color_palette("deep")
