# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Task 1 — Data Quality Assessment
# Objective
# Evaluate the quality of the dataset before analysis.
# Deliverables
# QUESTION:1 - Missing Value Report

df = pd.read_csv("tamil_movies.csv")
df.isnull().sum()
# Out:
# MovieName         0
# Genre             0
# Rating            0
# Director          0
# Actor             0
# PeopleVote        0
# Year              0
# Hero_Rating       0
# movie_rating      0
# content_rating    0
# dtype: int64

# %%
# QUESTION:2 - Duplicate Record Report

df = pd.read_csv("tamil_movies.csv")
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# QUESTION:3 - Data Type Validation
df = pd.read_csv("tamil_movies.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   MovieName       329 non-null    object
#  1   Genre           329 non-null    object
#  2   Rating          329 non-null    float64
#  3   Director        329 non-null    object
#  4   Actor           329 non-null    object
#  5   PeopleVote      329 non-null    int64
#  6   Year            329 non-null    int64
#  7   Hero_Rating     329 non-null    int64
#  8   movie_rating    329 non-null    int64
#  9   content_rating  329 non-null    float64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 25.8+ KB

# %%
# QUESTION:4 -  Invalid Value Detection

df = pd.read_csv("tamil_movies.csv")
df.isnull()
# Out:
#      MovieName  Genre  Rating  Director  Actor  PeopleVote   Year  \
# 0        False  False   False     False  False       False  False
# 1        False  False   False     False  False       False  False
# 2        False  False   False     False  False       False  False
# 3        False  False   False     False  False       False  False
# 4        False  False   False     False  False       False  False
# ..         ...    ...     ...       ...    ...         ...    ...
# 324      False  False   False     False  False       False  False
# 325      False  False   False     False  False       False  False
# 326      False  False   False     False  False       False  False
# 327      False  False   False     False  False       False  False
# 328      False  False   False     False  False       False  False
#
#      Hero_Rating  movie_rating  content_rating
# 0          False         False           False
# 1          False         False           False
# ...

# %%
# QUESTION:5 - Data Quality Score (%)
Data Quality Score(%) is 98.5

# %%
# Task 2 — Genre Performance Analysis
# Objective
# Determine which genres perform best.
# Requirements
# Calculate
# QUESTION:1 - Number of Movies

df = pd.read_csv("tamil_movies.csv")
len(df)
# Out:
# 329

# %%
# QUESTION:2 - Average Rating

df = pd.read_csv("tamil_movies.csv")
df["Rating"].mean()
# Out:
# np.float64(6.443161094224925)

# %%
# QUESTION:3 - Total Audience Votes

df = pd.read_csv("tamil_movies.csv")
df["PeopleVote"].sum()
# Out:
# np.int64(2425588)

# %%
# QUESTION:4 - Average Audience Votes

df = pd.read_csv("tamil_movies.csv")
df["PeopleVote"].mean()
# Out:
# np.float64(7372.607902735563)

# %%
# QUESTION:5 - Prepare
# Genre Ranking

df = pd.read_csv("tamil_movies.csv")
df["Genre"].max()
# Out:
# 'Thriller'

# %%
# Business Recommendation

Thirller are the highly rated genre this is good for investment

# %%
# Task 3 — Director Performance Index
# Objective
# Identify directors who consistently produce successful movies.
# Requirements
# For every director calculate

# Ranking director columns 

df = pd.read_csv("tamil_movies.csv")
df["Director"]
# Out:
# 0              Santha Kumar
# 1           A.R. Murugadoss
# 2               A. Sarkunam
# 3             Venkat Prabhu
# 4      Lawrence Raghavendra
#                ...
# 324                 Rambala
# 325      Rajath Ravishankar
# 326      Sakthi Chidambaram
# 327        Karthik Subbaraj
# 328                    Siva
# Name: Director, Length: 329, dtype: object

# %%
# QUESTION:1 - Total Movies

df["Director"].value_counts()
# Out:
# Director
# A.L. Vijay            7
# Karthik Subbaraj      5
# Suseenthiran          5
# A.R. Murugadoss       5
# Myshkin               4
#                      ..
# Meera Kathiravan      1
# Ravee Paargavan       1
# Bejoy Nambiar         1
# R. Panneerselvam      1
# Sakthi Chidambaram    1
# Name: count, Length: 233, dtype: int64

# %%
# QUESTION:2 - Average Rating

df.groupby("Director")["Rating"].mean()
# Out:
# Director
# A. Sarkunam        6.000000
# A.G. Amid          7.700000
# A.L. Vijay         5.985714
# A.R. Murugadoss    7.080000
# Abbas Akbaar       6.100000
#                      ...
# Vikram K. Kumar    7.800000
# Vikram Prabhu      4.800000
# Vishnuvardhan      7.000000
# Vishwaroopam       5.900000
# Vivek Elangovan    7.200000
# Name: Rating, Length: 233, dtype: float64

# %%
# QUESTION:3 - Total Votes

df = pd.read_csv("tamil_movies.csv")
df["PeopleVote"].sum()
# Out:
# np.int64(2425588)

# %%
# QUESTION:4 - Highest Rated Movie

df = pd.read_csv("tamil_movies.csv")
df["Rating"].max()
# Out:
# 9.0

# %%
# QUESTION:5 - Lowest Rated Movie

df = pd.read_csv("tamil_movies.csv")
df["Rating"].min()
# Out:
# 1.2

# %%
# Create
# Director Performance Score

df.groupby("Director")["Rating"].describe()
# Out:
#                  count      mean       std  min  25%  50%   75%  max
# Director
# A. Sarkunam        2.0  6.000000  2.828427  4.0  5.0  6.0  7.00  8.0
# A.G. Amid          1.0  7.700000       NaN  7.7  7.7  7.7  7.70  7.7
# A.L. Vijay         7.0  5.985714  1.405262  3.8  5.3  5.7  6.85  8.1
# A.R. Murugadoss    5.0  7.080000  0.779102  6.2  6.6  6.8  7.90  7.9
# Abbas Akbaar       1.0  6.100000       NaN  6.1  6.1  6.1  6.10  6.1
# ...                ...       ...       ...  ...  ...  ...   ...  ...
# Vikram K. Kumar    1.0  7.800000       NaN  7.8  7.8  7.8  7.80  7.8
# Vikram Prabhu      1.0  4.800000       NaN  4.8  4.8  4.8  4.80  4.8
# Vishnuvardhan      1.0  7.000000       NaN  7.0  7.0  7.0  7.00  7.0
# Vishwaroopam       1.0  5.900000       NaN  5.9  5.9  5.9  5.90  5.9
# Vivek Elangovan    1.0  7.200000       NaN  7.2  7.2  7.2  7.20  7.2
#
# [233 rows x 8 columns]

# %%
# Rank all directors.

df.groupby("Director")["Rating"].mean().sort_values(ascending=False)
# Out:
# Director
# Mari Selvaraj                8.8
# Gayatri                      8.7
# C. Prem Kumar                8.6
# Arun Prabhu Purushothaman    8.6
# Lenin Bharati                8.6
#                             ...
# Deepan                       2.7
# Prashanth Pandiraj           2.4
# Adhik Ravichandran           2.3
# Rajadurai                    1.6
# Kumaresh Kumar               1.2
# Name: Rating, Length: 233, dtype: float64

# %%
# Task 4 — Audience Behaviour Analysis
# Objective
# Study audience engagement.
# Requirements
# QUESTION:1 - Does higher rating always mean higher votes?

not for all time

# %%
# QUESTION:2 - Which movies are overrated?

df.sort_values(by="movie_rating",ascending=False).head()
# Out:
#             MovieName   Genre  Rating           Director                Actor  \
# 288        Kalavani 2  Comedy     4.0        A. Sarkunam                Vimal
# 328          Viswasam  Action     6.7               Siva          Ajith Kumar
# 238      Odu Raja Odu  Comedy     7.1  Jathin Sanker Raj  Nishanth Ravindaran
# 103   Muthuramalingam  Action     1.6          Rajadurai          Priya Anand
# 246  Tamizh Padam 2.0  Comedy     6.5       C.S. Amudhan                Jiiva
#
#      PeopleVote  Year  Hero_Rating  movie_rating  content_rating
# 288          68  2019            5            10        6.333333
# 328        5907  2019            8             9        7.900000
# 238          86  2018            9             9        8.366667
# 103       14063  2017            5             9        5.200000
# 246        1286  2018            9             9        8.166667

# %%
# QUESTION:3 - Which movies are underrated?

df.sort_values(by="movie_rating",ascending=False).tail()
# Out:
#          MovieName   Genre  Rating              Director            Actor  \
# 267  Adithya Varma   Drama     6.4            Gireesaaya     Dhruv Vikram
# 87          Ammani   Drama     7.9  Lakshmi Ramakrishnan   Semmalar Annam
# 319      Boomerang  Action     5.6             R. Kannan  Atharvaa Murali
# 320         Thadam  Action     8.2      Magizh Thirumeni       Arun Vijay
# 302           K-13  Action     6.1    Barath Neelakantan        Arulnithi
#
#      PeopleVote  Year  Hero_Rating  movie_rating  content_rating
# 267         596  2019            8             7        7.133333
# 87        52730  2016            9             7        7.966667
# 319         356  2019            7             6        6.200000
# 320        3728  2019            8             6        7.400000
# 302         359  2019            8             6        6.700000

# %%
# QUESTION:4 - Which movies are hidden gems?

df[(df["Rating"] >= 8.5) & (df["PeopleVote"] < 10000)]
# Out:
#              MovieName      Genre  Rating                   Director  \
# 64          Visaaranai      Crime     8.5                Vetrimaaran
# 117              Aruvi      Drama     8.6  Arun Prabhu Purushothaman
# 225       Vada Chennai     Action     8.5                Vetrimaaran
# 230  Pariyerum Perumal      Drama     8.8              Mari Selvaraj
# 250           Mahanati  Biography     8.5                    Savitri
# 268             Kaithi     Action     8.5           Lokesh Kanagaraj
# 271             Asuran     Action     8.6                Vetrimaaran
#
#            Actor  PeopleVote  Year  Hero_Rating  movie_rating  content_rating  \
# 64        Dinesh        6219  2015            8             9        8.500000
# 117  Aditi Balan        9890  2017            7             7        7.533333
# 225      Dhanush        8841  2018            8             8        8.166667
# 230    Prabunath        6984  2018            7             9        8.266667
# ...

# %%
# QUESTION:5 - Provide business explanation

based on the people voting the investment should be provided

# %%
# Task 5 — Movie Success Classification
# Create four business categories
# OUESTION:1 - Blockbuster

len(df[df["Rating"]>8.5])
# Out:
# 8

# %%
# QUESTION:2 - Hit

len(df[df["Rating"]>7.5])
# Out:
# 79

# %%
# QUESTION:3 - Average

len(df[df["Rating"]>6.5])
# Out:
# 171

# %%
# QUESTION:4 - Poor

len(df[df["Rating"]<6.5])
# Out:
# 148

# %%
# QUESTION:5 - Define your own business rules using
# Rating
# Audience Votes
# Generate a report showing the percentage of movies in each category

df.describe()
# Out:
#            Rating    PeopleVote         Year  Hero_Rating  movie_rating  \
# count  329.000000    329.000000   329.000000   329.000000    329.000000
# mean     6.443161   7372.607903  2016.562310     6.793313      8.139818
# std      1.403835  14380.829757     2.142039     1.959923      0.760232
# min      1.200000      7.000000  2011.000000     1.000000      6.000000
# 25%      5.600000    455.000000  2015.000000     5.000000      8.000000
# 50%      6.700000   1320.000000  2017.000000     7.000000      8.000000
# 75%      7.500000   5907.000000  2018.000000     8.000000      9.000000
# max      9.000000  71418.000000  2019.000000    10.000000     10.000000
#
#        content_rating  PopularityScore
# count      329.000000       329.000000
# mean         7.125431     48211.135258
# std          0.856000     92813.822270
# min          4.300000        23.800000
# 25%          6.666667      2520.800000
# 50%          7.200000      9058.400000
# 75%          7.766667     41752.000000
# ...

# %%
# Task 6 — Trend Analysis
# Analyze
# QUESTION:1 - Movie releases by year

df["Year"].hist()
plt.show()

# %%
# QUESTION:2 - Rating trend over years

sns.scatterplot(x="Year",y="Rating",data=df)
plt.show()

# %%
# QUESTION:3 - Audience engagement trend

sns.lineplot(x="Year",y="PeopleVote",data=df)
plt.show()

# %%
# QUESTION:4 - Growth rate

sns.boxplot(df["movie_rating"])
plt.show()

# %%
# Questions:5
# Has movie quality improved?
yes
# Has audience engagement increased?
yes

# %%
# Task 7 — Director–Genre Analysis

df.groupby("Director")["Genre"].unique()
# Out:
# Director
# A. Sarkunam                                 [Comedy]
# A.G. Amid                                   [Action]
# A.L. Vijay         [Drama, Action, Comedy, Thriller]
# A.R. Murugadoss                             [Action]
# Abbas Akbaar                                [Comedy]
#                                  ...
# Vikram K. Kumar                             [Action]
# Vikram Prabhu                               [Action]
# Vishnuvardhan                               [Action]
# Vishwaroopam                                [Action]
# Vivek Elangovan                              [Crime]
# Name: Genre, Length: 233, dtype: object

# %%
#  QUESTION:1
# Find
# Which directors dominate Action movies?

df[df["Genre"]=="Action"]["Director"]
# Out:
# 0                   Santha Kumar
# 1                A.R. Murugadoss
# 3                  Venkat Prabhu
# 6      Radha Krishna Jagarlamudi
# 7                     K.V. Anand
#                  ...
# 320             Magizh Thirumeni
# 323                    Sundar C.
# 325           Rajath Ravishankar
# 327             Karthik Subbaraj
# 328                         Siva
# Name: Director, Length: 146, dtype: object

# %%
# QUESTION:2 - Which directors dominate Comedy?

df[df["Genre"]=="Comedy"]["Director"]
# Out:
# 2                A. Sarkunam
# 4       Lawrence Raghavendra
# 11     Balaji Tharaneetharan
# 16                 Sundar C.
# 23             R.S. Prasanna
#                ...
# 312        Parthiban Desingu
# 321              Anita Udeep
# 322                   Prabhu
# 324                  Rambala
# 326       Sakthi Chidambaram
# Name: Director, Length: 62, dtype: object

# %%
# QUESTION:3 - Which director has the highest average rating in every genre?

df.groupby(["Genre","Director"])["Rating"].mean().sort_values(ascending=False)
# Out:
# Genre   Director
# Drama   Mari Selvaraj                8.8
# Action  Gayatri                      8.7
#         Ram Kumar                    8.7
# Drama   Lenin Bharati                8.6
#         Arun Prabhu Purushothaman    8.6
#                                     ...
# Action  Deepan                       2.7
#         Prashanth Pandiraj           2.4
#         Adhik Ravichandran           2.3
#         Rajadurai                    1.6
# Comedy  Kumaresh Kumar               1.2
# Name: Rating, Length: 275, dtype: float64

# %%
# QUESTION:4 - Generate a Pivot Table.
df.transpose
# Out:
# <bound method DataFrame.transpose of              MovieName   Genre  Rating              Director  \
# 0           Mouna Guru  Action     7.7          Santha Kumar
# 1          7 Aum Arivu  Action     6.2       A.R. Murugadoss
# 2     Vaagai Sooda Vaa  Comedy     8.0           A. Sarkunam
# 3             Mankatha  Action     7.6         Venkat Prabhu
# 4     Kanchana: Muni 2  Comedy     6.5  Lawrence Raghavendra
# ..                 ...     ...     ...                   ...
# 324  Dhilluku Dhuddu 2  Comedy     5.3               Rambala
# 325                Dev  Action     4.8    Rajath Ravishankar
# 326  Charlie Chaplin 2  Comedy     3.8    Sakthi Chidambaram
# 327              Petta  Action     7.3      Karthik Subbaraj
# 328           Viswasam  Action     6.7                  Siva
#
#                     Actor  PeopleVote  Year  Hero_Rating  movie_rating  \
# 0               Arulnithi         746  2011            8             8
# ...

# %%
# Task 8 — Popularity Score Engineering
# QUESTION:1 - Create a new feature
# Example
# Popularity Score = Rating × log(PeopleVote)
# Then
df["PopularityScore"] = df["Rating"] * (df["PeopleVote"])

# %%
# QUESTION:2 - Rank movies

df["MovieName"].sort_values(ascending=True)
# Out:
# 304                 100
# 270         100% Kadhal
# 125          12-12-1950
# 221                   2
# 96                   24
#              ...
# 173    Yaanum Theeyavan
# 105               Yaman
# 189           Yeidhavan
# 82     Yennai Arindhaal
# 9            Yutham Sei
# Name: MovieName, Length: 329, dtype: object

# %%
# QUESTION:3 - Rank actors

df["Actor"]
# Out:
# 0                 Arulnithi
# 1                    Suriya
# 2                     Vimal
# 3               Ajith Kumar
# 4      Lawrence Raghavendra
#                ...
# 324               Santhanam
# 325                  Karthi
# 326             Prabhu Deva
# 327             Rajinikanth
# 328             Ajith Kumar
# Name: Actor, Length: 329, dtype: object

# %%
# QUESTION:4 - Rank directors

df["Director"]
# Out:
# 0              Santha Kumar
# 1           A.R. Murugadoss
# 2               A. Sarkunam
# 3             Venkat Prabhu
# 4      Lawrence Raghavendra
#                ...
# 324                 Rambala
# 325      Rajath Ravishankar
# 326      Sakthi Chidambaram
# 327        Karthik Subbaraj
# 328                    Siva
# Name: Director, Length: 329, dtype: object

# %%
# QUESTION:5 - Explain why this metric is better than Rating alone

rating is based upon the people voting

# %%
df.groupby(["Actor"])["Rating"].mean().sort_values(ascending=False)
# Out:
# Actor
# Amudhavan Karuppiah    9.0
# Prabunath              8.8
# Pushkar                8.7
# Leninbharati           8.6
# Aditi Balan            8.6
#                       ...
# Roma Asrani            2.7
# Anandraj               2.4
# Tamannaah Bhatia       2.3
# Priya Anand            1.6
# Sreeja Das             1.2
# Name: Rating, Length: 178, dtype: float64

# %%
# Task 9 — Executive Presentation (using PPT or Doc)
# Prepare a report answering
# Which genre should the company invest in?
 In Thirller genre the company should invest
# Which directors should receive priority contracts?
 Directors Mari Selvaraj should receivr the priority contracts
# Which movies are hidden gems?
# Which actors consistently appear in highly rated movies?
Amudhavan Karuppiah actor is consistently appear in highly rated movies
# Which year produced the strongest movies?
In the year of 2017 produced the strongest movies
# Which genres should be avoided?
Action genre should be avoided because it has low rating 
# What factors most influence audience popularity?
Audience popularity is most influenced by genre,rating and actor
# Give five strategic recommendations for the OTT platform
Invest More in High-Rated Genres
Promote Hidden Gems
Collaborate with Top Directors and Actors
Analyze which directors and actors consistently deliver successful movies.
Use Personalized Recommendation Systems
Personalized content keeps users engaged and increases subscription renewal.
Invest in content that has the highest potential for audience engagement and ROI.
